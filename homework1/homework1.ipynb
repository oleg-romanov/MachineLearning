# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
male_df = df.loc[df['Sex'] == "male"]
female_df = df.loc[df['Sex'] == "female"]

# %%
first_pclass_male_df = male_df.loc[df['Pclass'] == 1]
second_pclass_male_df = male_df.loc[df['Pclass'] == 2]
third_pclass_male_df = male_df.loc[df['Pclass'] == 3]

# %%
first_pclass_female_df = female_df.loc[df['Pclass'] == 1]
second_pclass_female_df = female_df.loc[df['Pclass'] == 2]
third_pclass_female_df = female_df.loc[df['Pclass'] == 3]

# %%
male_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 577 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  577 non-null    int64
#  1   Survived     577 non-null    int64
#  2   Pclass       577 non-null    int64
#  3   Name         577 non-null    object
#  4   Sex          577 non-null    object
#  5   Age          453 non-null    float64
#  6   SibSp        577 non-null    int64
#  7   Parch        577 non-null    int64
#  8   Ticket       577 non-null    object
#  9   Fare         577 non-null    float64
#  10  Cabin        107 non-null    object
#  11  Embarked     577 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 58.6+ KB

# %%
female_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 314 entries, 1 to 888
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  314 non-null    int64
#  1   Survived     314 non-null    int64
#  2   Pclass       314 non-null    int64
#  3   Name         314 non-null    object
#  4   Sex          314 non-null    object
#  5   Age          261 non-null    float64
#  6   SibSp        314 non-null    int64
#  7   Parch        314 non-null    int64
#  8   Ticket       314 non-null    object
#  9   Fare         314 non-null    float64
#  10  Cabin        97 non-null     object
#  11  Embarked     312 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 31.9+ KB

# %%
male_survived_df = male_df.loc[male_df['Survived'] == 1]
male_survived_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 109 entries, 17 to 889
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  109 non-null    int64
#  1   Survived     109 non-null    int64
#  2   Pclass       109 non-null    int64
#  3   Name         109 non-null    object
#  4   Sex          109 non-null    object
#  5   Age          93 non-null     float64
#  6   SibSp        109 non-null    int64
#  7   Parch        109 non-null    int64
#  8   Ticket       109 non-null    object
#  9   Fare         109 non-null    float64
#  10  Cabin        45 non-null     object
#  11  Embarked     109 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 11.1+ KB

# %%
female_survived_df = female_df.loc[female_df['Survived'] == 1]
female_survived_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 233 entries, 1 to 887
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  233 non-null    int64
#  1   Survived     233 non-null    int64
#  2   Pclass       233 non-null    int64
#  3   Name         233 non-null    object
#  4   Sex          233 non-null    object
#  5   Age          197 non-null    float64
#  6   SibSp        233 non-null    int64
#  7   Parch        233 non-null    int64
#  8   Ticket       233 non-null    object
#  9   Fare         233 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     231 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 23.7+ KB

# %%
first_pclass_survived_male = male_survived_df.loc[male_survived_df['Pclass'] == 1]

# %%
first_pclass_survived_female = female_survived_df.loc[female_survived_df['Pclass'] == 1]

# %%
first_pclass_survived_male.head(100)
# Out:
#      PassengerId  Survived  Pclass  \
# 23            24         1       1
# 55            56         1       1
# 97            98         1       1
# 187          188         1       1
# 209          210         1       1
# 224          225         1       1
# 248          249         1       1
# 298          299         1       1
# 305          306         1       1
# 370          371         1       1
# 390          391         1       1
# 430          431         1       1
# 445          446         1       1
# 447          448         1       1
# 449          450         1       1
# 453          454         1       1
# 460          461         1       1
# 484          485         1       1
# 507          508         1       1
# 512          513         1       1
# 550          551         1       1
# 572          573         1       1
# 587          588         1       1
# 599          600         1       1
# 604          605         1       1
# ...

# %%
second_pclass_survived_male = male_survived_df.loc[male_survived_df['Pclass'] == 2]

# %%
second_pclass_survived_female = female_survived_df.loc[female_survived_df['Pclass'] == 2]

# %%
third_pclass_survived_male = male_survived_df.loc[male_survived_df['Pclass'] == 3]

# %%
third_pclass_survived_female = female_survived_df.loc[female_survived_df['Pclass'] == 3]

# %%
third_pclass_survived_male["Pclass"].value_counts()
# Out:
# 3    47
# Name: Pclass, dtype: int64

# %%
first_survived_male_count = first_pclass_survived_male["PassengerId"].count()
second_survived_male_count = second_pclass_survived_male["PassengerId"].count()
third_survived_male_count = third_pclass_survived_male["PassengerId"].count()

# %%
print(first_survived_male_count)
# Out:
# 45

# %%
all_first_pclass_male = first_pclass_male_df["PassengerId"].count()
all_second_pclass_male = second_pclass_male_df["PassengerId"].count()
all_third_pclass_male = third_pclass_male_df["PassengerId"].count()

# %%
first_survived_female_count = first_pclass_survived_female["PassengerId"].count()
second_survived_female_count = second_pclass_survived_female["PassengerId"].count()
third_survived_female_count = third_pclass_survived_female["PassengerId"].count()

# %%
all_first_pclass_female = first_pclass_female_df["PassengerId"].count()
all_second_pclass_female = second_pclass_female_df["PassengerId"].count()
all_third_pclass_female = third_pclass_female_df["PassengerId"].count()

# %%
vals_first_pclass = [first_survived_male_count, all_first_pclass_male]
vals_second_pclass = [second_survived_male_count, all_second_pclass_male]
vals_third_pclass = [third_survived_male_count, all_third_pclass_male]

# %%
print(first_survived_male_count)
# Out:
# 45

# %%
labels = ["survived Male", "All Male"]

# %%
# Распределение выживших пассажиров мужчин в 1-м классе

plt.bar(labels, [first_survived_male_count/all_first_pclass_male*100 , 100])
plt.show()

# %%
# Распределение выживших пассажиров женщин в 1-м классе

plt.bar(labels, [first_survived_female_count/all_first_pclass_female*100 , 100])
plt.show()

# %%
# Распределение выживших пассажиров мужчин в 2-м классе
plt.bar(labels, [second_survived_male_count/all_second_pclass_male*100 , 100])
plt.show()

# %%
# Распределение выживших пассажиров женщин в 2-м классе
plt.bar(labels, [second_survived_female_count/all_second_pclass_female*100 , 100])
plt.show()

# %%
# Распределение выживших пассажиров мужчин в 3-м классе
plt.bar(labels, [third_survived_male_count/all_third_pclass_male*100 , 100])
plt.show()

# %%
# Распределение выживших пассажиров женщин в 3-м классе
plt.bar(labels, [third_survived_female_count/all_third_pclass_female*100 , 100])
plt.show()

# %%
# количество людей в первом, втором и третьем классе
first_pclass_people_count = df.loc[df['Pclass'] == 1]["PassengerId"].count()
second_pclass_people_count = df.loc[df['Pclass'] == 2]["PassengerId"].count()
third_pclass_people_count = df.loc[df['Pclass'] == 3]["PassengerId"].count()

# %%
pclasses = df["Pclass"].value_counts()
print(pclasses)
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
# Круговая диаграмма для признака "класс пассажира" (количество людей в каждом классе)
fig1, ax1 = plt.subplots()
ax1.pie(pclasses, labels= pclasses.index, autopct='%1.1f%%')
plt.show()

# %%
ages = df["Age"]
passengers_id = df["PassengerId"]

# %%
print(ages)
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
plt.figure(figsize=(66,10))
plt.plot(passengers_id, ages)
plt.show()
